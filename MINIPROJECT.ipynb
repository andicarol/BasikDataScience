# %% [markdown]
# # Mini Projek

# %% [markdown]
# ## Import Package

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os 

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans

# %% [markdown]
# ## Data Overview

# %%
data_path = os.path.join("Mini Projek", "lead_scoring.csv")
print(data_path)
# Out:
# Mini Projek\lead_scoring.csv

# %%
data = pd.read_csv(data_path)

# %%
data.shape
# Out:
# (9240, 37)

# %%
data.head()
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# 0      Olark Chat           No          No          0          0.0
# 1  Organic Search           No          No          0          5.0
# 2  Direct Traffic           No          No          1          2.0
# 3  Direct Traffic           No          No          0          1.0
# 4          Google           No          No          1          2.0
#
#    Total Time Spent on Website  Page Views Per Visit  ...  \
# ...

# %%
data.tail()
# Out:
#                                Prospect ID  Lead Number  \
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 9235  Landing Page Submission  Direct Traffic          Yes          No
# 9236  Landing Page Submission  Direct Traffic           No          No
# 9237  Landing Page Submission  Direct Traffic          Yes          No
# 9238  Landing Page Submission          Google           No          No
# 9239  Landing Page Submission  Direct Traffic           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 9235          1          8.0                         1845
# 9236          0          2.0                          238
# ...

# %%
data.sample(5, random_state=91)
# Out:
#                                Prospect ID  Lead Number  \
# 6936  2154ccbd-41f9-46f0-9edb-308cde9fc52d       596447
# 2140  5f05a482-8fb5-4fe8-aca3-0f7b9d794178       639211
# 4377  2be87f90-5931-49dc-bb87-54d8452cb693       617791
# 5208  65e13a16-f5c0-49a1-8187-a4795a5941fb       609879
# 1041  0adb324b-c2a3-4880-a928-6e1589914ab4       649091
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 6936  Landing Page Submission          Google           No          No
# 2140            Lead Add Form       Reference           No          No
# 4377  Landing Page Submission          Google           No          No
# 5208  Landing Page Submission  Direct Traffic           No          No
# 1041  Landing Page Submission          Google           No          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 6936          0          2.0                          238
# 2140          1          0.0                            0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Prospect ID                                     9240 non-null   object
#  1   Lead Number                                     9240 non-null   int64
#  2   Lead Origin                                     9240 non-null   object
#  3   Lead Source                                     9204 non-null   object
#  4   Do Not Email                                    9240 non-null   object
#  5   Do Not Call                                     9240 non-null   object
#  6   Converted                                       9240 non-null   int64
#  7   TotalVisits                                     9103 non-null   float64
#  8   Total Time Spent on Website                     9240 non-null   int64
# ...

# %% [markdown]
# ## Data Quality Check

# %%
data["Lead Source"].unique()
# Out:
# array(['Olark Chat', 'Organic Search', 'Direct Traffic', 'Google',
#        'Referral Sites', 'Welingak Website', 'Reference', 'google',
#        'Facebook', nan, 'blog', 'Pay per Click Ads', 'bing',
#        'Social Media', 'WeLearn', 'Click2call', 'Live Chat',
#        'welearnblog_Home', 'youtubechannel', 'testone', 'Press_Release',
#        'NC_EDM'], dtype=object)

# %%
data["TotalVisits"].unique()
# Out:
# array([  0.,   5.,   2.,   1.,   4.,   8.,  11.,   6.,   3.,   7.,  13.,
#         17.,  nan,   9.,  12.,  10.,  16.,  14.,  21.,  15.,  22.,  19.,
#         18.,  20.,  43.,  30.,  23.,  55., 141.,  25.,  27.,  29.,  24.,
#         28.,  26.,  74.,  41.,  54., 115., 251.,  32.,  42.])

# %%
data.describe(include='O') #untuk melihat pesebaran data categorik
# Out:
#                                  Prospect ID              Lead Origin  \
# count                                   9240                     9240
# unique                                  9240                        5
# top     7927b2df-8bba-4d29-b9a2-b6e0beafe620  Landing Page Submission
# freq                                       1                     4886
#
#        Lead Source Do Not Email Do Not Call Last Activity    Country  \
# count         9204         9240        9240          9137       6779
# unique          21            2           2            17         38
# top         Google           No          No  Email Opened  Indonesia
# freq          2868         8506        9238          3437       6492
#
#        Specialization How did you hear about Madugital  \
# count            7802                             7033
# unique             19                               10
# top            Select                           Select
# ...

# %%
data.describe() #untuk melihat pesebaran data numerik
# Out:
#          Lead Number    Converted  TotalVisits  Total Time Spent on Website  \
# count    9240.000000  9240.000000  9103.000000                  9240.000000
# mean   617188.435606     0.385390     3.445238                   487.698268
# std     23405.995698     0.486714     4.854853                   548.021466
# min    579533.000000     0.000000     0.000000                     0.000000
# 25%    596484.500000     0.000000     1.000000                    12.000000
# 50%    615479.000000     0.000000     3.000000                   248.000000
# 75%    637387.250000     1.000000     5.000000                   936.000000
# max    660737.000000     1.000000   251.000000                  2272.000000
#
#        Page Views Per Visit  Asymmetrique Activity Score  \
# count           9103.000000                  5022.000000
# mean               2.362820                    14.306252
# std                2.161418                     1.386694
# ...

# %%
data.isnull().sum() #melihat value yang kosong
# Out:
# Prospect ID                                          0
# Lead Number                                          0
# Lead Origin                                          0
# Lead Source                                         36
# Do Not Email                                         0
# Do Not Call                                          0
# Converted                                            0
# TotalVisits                                        137
# Total Time Spent on Website                          0
# Page Views Per Visit                               137
# Last Activity                                      103
# Country                                           2461
# Specialization                                    1438
# How did you hear about Madugital                  2207
# What is your current occupation                   2690
# What matters most to you in choosing a product    2709
# Search                                               0
# ...

# %%
#melihat persentase baris yang kosong dari keseluruhan 
#(jika persentasi lebih dari 60% lebih baik di dropna saja, di bawah 60% masih bisa di fillna)
data.isna().mean()*100
# Out:
# Prospect ID                                        0.000000
# Lead Number                                        0.000000
# Lead Origin                                        0.000000
# Lead Source                                        0.389610
# Do Not Email                                       0.000000
# Do Not Call                                        0.000000
# Converted                                          0.000000
# TotalVisits                                        1.482684
# Total Time Spent on Website                        0.000000
# Page Views Per Visit                               1.482684
# Last Activity                                      1.114719
# Country                                           26.634199
# Specialization                                    15.562771
# How did you hear about Madugital                  23.885281
# What is your current occupation                   29.112554
# What matters most to you in choosing a product    29.318182
# ...

# %%
data_dropped = data.dropna()
data_dropped.isnull().sum()
# Out:
# Prospect ID                                       0
# Lead Number                                       0
# Lead Origin                                       0
# Lead Source                                       0
# Do Not Email                                      0
# Do Not Call                                       0
# Converted                                         0
# TotalVisits                                       0
# Total Time Spent on Website                       0
# Page Views Per Visit                              0
# Last Activity                                     0
# Country                                           0
# Specialization                                    0
# How did you hear about Madugital                  0
# What is your current occupation                   0
# What matters most to you in choosing a product    0
# Search                                            0
# Magazine                                          0
# ...

# %%
data.shape, data_dropped.shape
# Out:
# ((9240, 37), (1943, 37))

# %%
data_dropped = data.drop(columns=['Lead Quality'], axis =1)
data_dropped.isnull().sum()
# Out:
# Prospect ID                                          0
# Lead Number                                          0
# Lead Origin                                          0
# Lead Source                                         36
# Do Not Email                                         0
# Do Not Call                                          0
# Converted                                            0
# TotalVisits                                        137
# Total Time Spent on Website                          0
# Page Views Per Visit                               137
# Last Activity                                      103
# Country                                           2461
# Specialization                                    1438
# How did you hear about Madugital                  2207
# What is your current occupation                   2690
# What matters most to you in choosing a product    2709
# Search                                               0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Prospect ID                                     9240 non-null   object
#  1   Lead Number                                     9240 non-null   int64
#  2   Lead Origin                                     9240 non-null   object
#  3   Lead Source                                     9204 non-null   object
#  4   Do Not Email                                    9240 non-null   object
#  5   Do Not Call                                     9240 non-null   object
#  6   Converted                                       9240 non-null   int64
#  7   TotalVisits                                     9103 non-null   float64
#  8   Total Time Spent on Website                     9240 non-null   int64
# ...

# %%
data_dropped.loc[data_dropped['Lead Source'].isnull()]
# Out:
#                                Prospect ID  Lead Number  \
# 836   b2dfb7a5-814d-465b-816e-63d6b3a863ca       651660
# 1569  1c87e9fd-c675-468e-9653-2cc968f077f2       643899
# 1746  215e9984-818a-42ff-ba1c-667ce73199a5       642394
# 2020  06f5b430-a45a-4de2-9aca-e13ee0a43589       640115
# 2025  e7524e35-923e-4c9f-800d-b18e1a6c5e3b       640081
# 2152  e54f76cc-2436-451c-8a29-fcd32ed7bed4       639134
# 2346  c309cc6d-204f-4ac0-a766-7d326bd01218       637125
# 2544  175611de-436d-11e6-b61b-22000aa8e760       635028
# 2601  bbe44370-ea5a-4e46-99d9-d32cfbd32199       634618
# 2676  bcfdd00e-99d2-4be1-b09b-a6260a63dade       633945
# 3028  6238e5d6-2708-4d78-8180-82fd603c8a22       630801
# 3266  1081fb9a-3309-46b6-a890-74de644e05c8       628685
# 3268  4a959213-0cef-4b5f-bab0-9198557b5d8f       628666
# 3928  829524dc-e9c8-4f6d-8947-591e1c1746b0       622403
# 3945  f7aa46f0-2fe2-459a-8235-66e132910778       622280
# 4406  348bc75a-dbb6-4605-8d4a-fb02da9d48e2       617520
# ...

# %%
data_dropped['Lead Source_filled'] = data_dropped['Lead Source'].fillna('Missing')

# %%
data_dropped.loc[data_dropped['Lead Source'].isnull()]
# Out:
#                                Prospect ID  Lead Number  \
# 836   b2dfb7a5-814d-465b-816e-63d6b3a863ca       651660
# 1569  1c87e9fd-c675-468e-9653-2cc968f077f2       643899
# 1746  215e9984-818a-42ff-ba1c-667ce73199a5       642394
# 2020  06f5b430-a45a-4de2-9aca-e13ee0a43589       640115
# 2025  e7524e35-923e-4c9f-800d-b18e1a6c5e3b       640081
# 2152  e54f76cc-2436-451c-8a29-fcd32ed7bed4       639134
# 2346  c309cc6d-204f-4ac0-a766-7d326bd01218       637125
# 2544  175611de-436d-11e6-b61b-22000aa8e760       635028
# 2601  bbe44370-ea5a-4e46-99d9-d32cfbd32199       634618
# 2676  bcfdd00e-99d2-4be1-b09b-a6260a63dade       633945
# 3028  6238e5d6-2708-4d78-8180-82fd603c8a22       630801
# 3266  1081fb9a-3309-46b6-a890-74de644e05c8       628685
# 3268  4a959213-0cef-4b5f-bab0-9198557b5d8f       628666
# 3928  829524dc-e9c8-4f6d-8947-591e1c1746b0       622403
# 3945  f7aa46f0-2fe2-459a-8235-66e132910778       622280
# 4406  348bc75a-dbb6-4605-8d4a-fb02da9d48e2       617520
# ...

# %%
data_dropped.shape
# Out:
# (9240, 37)

# %%
#numerikal
data_dropped['TotalVisits'] = data_dropped['TotalVisits'].fillna(method='ffill')
data_dropped['Page Views Per Visit'] = data_dropped['Page Views Per Visit'].fillna(method='ffill')
data_dropped['Asymmetrique Activity Score']=data_dropped['Asymmetrique Activity Score'].fillna(method='ffill')
data_dropped['Asymmetrique Profile Score']=data_dropped['Asymmetrique Profile Score'].fillna(method='ffill')

#categorik
data_dropped['Lead Source']=data_dropped['Lead Source'].fillna(data_dropped['Lead Source'].value_counts().idxmax())
data_dropped['Last Activity']=data_dropped['Last Activity'].fillna(data_dropped['Last Activity'].value_counts().idxmax())
data_dropped['Country']=data_dropped['Country'].fillna(data_dropped['Country'].value_counts().idxmax())
data_dropped['Specialization']=data_dropped['Specialization'].fillna(data_dropped['Specialization'].value_counts().idxmax())
data_dropped['How did you hear about Madugital'] = data_dropped['How did you hear about Madugital'].fillna(data_dropped['How did you hear about Madugital'].value_counts().idxmax())
data_dropped['What is your current occupation'] = data_dropped['What is your current occupation'].fillna(data_dropped['What is your current occupation'].value_counts().idxmax())
data_dropped['What matters most to you in choosing a product'] = data_dropped['What matters most to you in choosing a product'].fillna(data_dropped['What matters most to you in choosing a product'].value_counts().idxmax())
data_dropped['Tags']=data_dropped['Tags'].fillna(data_dropped['Tags'].value_counts().idxmax())
data_dropped['Lead Profile']=data_dropped['Lead Profile'].fillna(data_dropped['Lead Profile'].value_counts().idxmax())
data_dropped['City']=data_dropped['City'].fillna(data_dropped['City'].value_counts().idxmax())
data_dropped['Asymmetrique Activity Index']=data_dropped['Asymmetrique Activity Index'].fillna(data_dropped['Asymmetrique Activity Index'].value_counts().idxmax())
data_dropped['Asymmetrique Profile Index']=data_dropped['Asymmetrique Profile Index'].fillna(data_dropped['Asymmetrique Profile Index'].value_counts().idxmax())

# %%
data_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9240 entries, 0 to 9239
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Prospect ID                                     9240 non-null   object
#  1   Lead Number                                     9240 non-null   int64
#  2   Lead Origin                                     9240 non-null   object
#  3   Lead Source                                     9240 non-null   object
#  4   Do Not Email                                    9240 non-null   object
#  5   Do Not Call                                     9240 non-null   object
#  6   Converted                                       9240 non-null   int64
#  7   TotalVisits                                     9240 non-null   float64
#  8   Total Time Spent on Website                     9240 non-null   int64
# ...

# %% [markdown]
# ## Handling Duplicate Column

# %%
data_dropped.loc[data_dropped['Prospect ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Prospect ID, Lead Number, Lead Origin, Lead Source, Do Not Email, Do Not Call, Converted, TotalVisits, Total Time Spent on Website, Page Views Per Visit, Last Activity, Country, Specialization, How did you hear about Madugital, What is your current occupation, What matters most to you in choosing a product, Search, Magazine, Newspaper Article, Madugital Telegram, Newspaper, Digital Advertisement, Through Recommendations, Receive More Updates About Our Products, Tags, Update me on Supply Chain Content, Get updates on DM Content, Lead Profile, City, Asymmetrique Activity Index, Asymmetrique Profile Index, Asymmetrique Activity Score, Asymmetrique Profile Score, I agree to pay the amount through cheque, A free copy of Mastering The Interview, Last Notable Activity, Lead Source_filled]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# ## Finding Data Insight

# %%
#agregat data berdasarkan suatu colomn 
data_dropped.groupby('Converted').mean()[['Total Time Spent on Website']]
# Out:
#            Total Time Spent on Website
# Converted
# 0                           330.404473
# 1                           738.546757

# %%
data_dropped.groupby('Converted').mean()[['TotalVisits']]
# Out:
#            TotalVisits
# Converted
# 0             3.317485
# 1             3.618085

# %%
data_dropped.groupby('Asymmetrique Activity Index').mean()[['Asymmetrique Activity Score']]
# Out:
#                              Asymmetrique Activity Score
# Asymmetrique Activity Index
# 01.High                                        16.437272
# 02.Medium                                      14.273054
# 03.Low                                         11.290055

# %%
data_dropped.groupby('Asymmetrique Profile Index').mean()[['Asymmetrique Profile Score']]
# Out:
#                             Asymmetrique Profile Score
# Asymmetrique Profile Index
# 01.High                                      18.128007
# 02.Medium                                    16.158864
# 03.Low                                       11.709677

# %%
#menghitung hubungan antara 2 variable
# pd.crosstab(data_dropped['Asymmetrique Activity Index'], data_dropped['Asymmetrique Activity Score']) #hanya menunjukan valuesnya saja (kurang bisa di pahami)
pd.crosstab(data_dropped['Asymmetrique Activity Index'], data_dropped['Asymmetrique Activity Score'],normalize=True)
# Out:
# Asymmetrique Activity Score      7.0       8.0       9.0       10.0      11.0  \
# Asymmetrique Activity Index
# 01.High                      0.000000  0.000000  0.000000  0.000000  0.000000
# 02.Medium                    0.000000  0.000000  0.000000  0.007143  0.012879
# 03.Low                       0.000108  0.000433  0.000974  0.006169  0.010281
#
# Asymmetrique Activity Score      12.0      13.0      14.0    15.0      16.0  \
# Asymmetrique Activity Index
# 01.High                      0.000000  0.000000  0.000000  0.0000  0.050541
# 02.Medium                    0.016017  0.133333  0.351623  0.2671  0.048052
# 03.Low                       0.021212  0.000000  0.000000  0.0000  0.000000
#
# Asymmetrique Activity Score      17.0      18.0
# Asymmetrique Activity Index
# 01.High                      0.037771  0.000541
# 02.Medium                    0.035823  0.000000
# 03.Low                       0.000000  0.000000

# %%
pd.crosstab(data_dropped['Asymmetrique Profile Index'], data_dropped['Asymmetrique Profile Score'], normalize=True)
# Out:
# Asymmetrique Profile Score      11.0      12.0      13.0      14.0      15.0  \
# Asymmetrique Profile Index
# 01.High                     0.000000  0.000000  0.000000  0.000000  0.000000
# 02.Medium                   0.000000  0.001190  0.028355  0.045346  0.294264
# 03.Low                      0.000974  0.002381  0.000000  0.000000  0.000000
#
# Asymmetrique Profile Score      16.0      17.0      18.0      19.0      20.0
# Asymmetrique Profile Index
# 01.High                     0.000000  0.062662  0.115909  0.026515  0.033333
# 02.Medium                   0.123268  0.061797  0.125649  0.031277  0.047078
# 03.Low                      0.000000  0.000000  0.000000  0.000000  0.000000

# %%
pd.crosstab(data_dropped['Converted'], data_dropped['Asymmetrique Activity Index'], normalize=True)
# Out:
# Asymmetrique Activity Index   01.High  02.Medium    03.Low
# Converted
# 0                            0.062338   0.516667  0.035606
# 1                            0.026515   0.355303  0.003571

# %%
pd.crosstab(data_dropped['Converted'], data_dropped['Asymmetrique Profile Index'], normalize=True)
# Out:
# Asymmetrique Profile Index   01.High  02.Medium    03.Low
# Converted
# 0                           0.125325   0.487554  0.001732
# 1                           0.113095   0.270671  0.001623

# %% [markdown]
# # Data manipulation

# %% [markdown]
# ## Binning

# %%
#membagi data numerik sesuai kuantilnya
data_dropped['Deal'] = np.where(data_dropped['Converted'] == 1 , 'YES' , 'NO')

# %%
data_dropped.loc[data_dropped['Deal']=='YES']
# Out:
#                                Prospect ID  Lead Number  \
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681
# 6     9fae7df4-169d-489b-afe4-0f3d752542ed       660673
# 10    2a369e35-ca95-4ca9-9e4f-9d27175aa320       660608
# 11    9bc8ce93-6144-49e0-9f9d-080fc980f83c       660570
# ...                                    ...          ...
# 9233  3f715465-2546-47cd-afa8-8b8dc63b8b43       579622
# 9234  c0b25922-511f-4c56-852e-ced210a45447       579615
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 2     Landing Page Submission  Direct Traffic           No          No
# 4     Landing Page Submission          Google           No          No
# 6     Landing Page Submission          Google           No          No
# ...

# %%
data_dropped.sample(5)
# Out:
#                                Prospect ID  Lead Number  \
# 6186  dbeb1e99-b6e5-44e5-85d5-67017754e8b7       602359
# 8321  7a6fc0c2-6448-4115-b53c-6da807ee760a       586345
# 3190  86c1c858-6e3d-407a-a817-91c6fd60bea8       629468
# 5112  898fe0e9-7438-49d2-977b-a1cd60d803cf       610781
# 1669  df24a8c0-e4a3-4a30-a729-1462c9fe3c20       643088
#
#                   Lead Origin     Lead Source Do Not Email Do Not Call  \
# 6186  Landing Page Submission  Direct Traffic           No          No
# 8321                      API      Olark Chat           No          No
# 3190                      API  Organic Search           No          No
# 5112  Landing Page Submission  Direct Traffic          Yes          No
# 1669  Landing Page Submission          Google          Yes          No
#
#       Converted  TotalVisits  Total Time Spent on Website  \
# 6186          1          2.0                          848
# 8321          1          0.0                            0
# ...

# %% [markdown]
# ## Clipping

# %%
#membatasi nilai dari 1 - 100
data_dropped['Page Views Per Visit'] = data_dropped['Page Views Per Visit'].clip(1,100)

# %%
data_dropped['Page Views Per Visit'].describe()
# Out:
# count    9240.000000
# mean        2.592335
# std         1.837692
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        15.000000
# Name: Page Views Per Visit, dtype: float64

# %% [markdown]
# # Modelling Preparation

# %%
data_dropped.columns
# Out:
# Index(['Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score', 'Deal'],
#       dtype='object')

# %%
data_dropped = data_droppe.drop(['Prospect ID', 'Lead Number', 'Lead Origin', 'Lead Source',
       'Do Not Email', 'Do Not Call','Last Activity',
       'Country', 'Specialization', 'How did you hear about Madugital',
       'What is your current occupation',
       'What matters most to you in choosing a product', 'Search', 'Magazine',
       'Newspaper Article', 'Madugital Telegram', 'Newspaper',
       'Digital Advertisement', 'Through Recommendations',
       'Receive More Updates About Our Products', 'Tags',
       'Update me on Supply Chain Content', 'Get updates on DM Content',
       'Lead Profile', 'City','I agree to pay the amount through cheque',
       'A free copy of Mastering The Interview', 'Last Notable Activity',
       'Lead Source_filled'],1)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/928179160.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data_dropped = data_dropped.drop(['Prospect ID', 'Lead Origin', 'Lead Source',
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5660/928179160.py in <module>
# ----> 1 data_dropped = data_dropped.drop(['Prospect ID', 'Lead Origin', 'Lead Source',
#       2        'Do Not Email', 'Do Not Call','Last Activity',
#       3        'Country', 'Specialization', 'How did you hear about Madugital',
#       4        'What is your current occupation',
#       5        'What matters most to you in choosing a product', 'Search', 'Magazine',
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data_dropped, test_size=0.3, random_state=2021)

# %%
train.shape, test.shape
# Out:
# ((6468, 9), (2772, 9))

# %% [markdown]
# # Modelling

# %%
train.columns
# Out:
# Index(['Converted', 'TotalVisits', 'Total Time Spent on Website',
#        'Page Views Per Visit', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score', 'Deal'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
# X = prediktor, y = target

X_train =train.drop(['Converted','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
y_train =train['Converted']
X_test =test.drop(['Converted','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
y_test =test['Converted']

lr = LinearRegression(normalize=True)
lr.fit(X_train, y_train)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/861940825.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train =train.drop(['Converted','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/861940825.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test =test.drop(['Converted','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# LinearRegression(normalize=True)

# %%
X_test[2:3]
# Out:
#       TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 9209          1.0                         1226                   1.0
#
#       Asymmetrique Activity Score  Asymmetrique Profile Score
# 9209                         14.0                        18.0

# %%
lr.predict(X_test[2:3])
# Out:
# array([0.69278161])

# %%
from sklearn.tree import DecisionTreeClassifier

X_train =train.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
y_train =train['TotalVisits']
X_test =test.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
y_test =test['TotalVisits']

dt= DecisionTreeClassifier(max_depth=10, min_samples_split=5,random_state=2021)
dt.fit(X_train, y_train)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/2278936667.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train =train.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/2278936667.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_test =test.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# DecisionTreeClassifier(max_depth=10, min_samples_split=5, random_state=2021)

# %%
X_test[2:3]
# Out:
#       Converted  Total Time Spent on Website  Page Views Per Visit  \
# 9209          0                         1226                   1.0
#
#       Asymmetrique Activity Score  Asymmetrique Profile Score
# 9209                         14.0                        18.0

# %%
dt.predict(X_test[2:3])
# Out:
# array([2.])

# %%
from sklearn.cluster import KMeans

X_train = train.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
y_test = test.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)

KMeans = KMeans(n_clusters=5, max_iter=100)
KMeans.fit(X_train)
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/2005113647.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   X_train = train.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5660/2005113647.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   y_test = test.drop(['TotalVisits','Deal','Asymmetrique Profile Index', 'Asymmetrique Activity Index'],1)
# KMeans(max_iter=100, n_clusters=5)

# %%
X_test[2:3]
# Out:
#       Converted  Total Time Spent on Website  Page Views Per Visit  \
# 9209          0                         1226                   1.0
#
#       Asymmetrique Activity Score  Asymmetrique Profile Score
# 9209                         14.0                        18.0

# %%
KMeans.predict(X_train[2:3])
# Out:
# array([0])

# %% [markdown]
# # Data Evaluation

# %%
from sklearn.metrics import mean_squared_error, accuracy_score, precision_score, recall_score, silhouette_score

# %%
#regresion
y_pred = lr.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 0.1983498794262025

# %%
#classification
y_pred = dt.predict(X_test)
acc = accuracy_score(y_test, y_pred)
# prec = precision_score(y_test, y_pred)
#recall = recall_score(y_test, y_pred)
print(acc)
# Out:
# 0.8690476190476191

# %%
#KMeans / Clustering
silhouette_score(X_train, KMeans.labels_)
# Out:
# 0.6314487849691619
